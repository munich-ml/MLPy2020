# %%
# %matplotlib notebook
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0, 10, 0.1)
FREQ = 0.2
s = np.sin(2 * np.pi * FREQ * t)

# %%
plt.plot(t,s)
plt.grid()
